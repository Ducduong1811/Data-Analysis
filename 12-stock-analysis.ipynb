# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
import plotly.graph_objects as go
import plotly.express as px

# %%
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1

d2 = date.today() - timedelta(days=365)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

# %%
data = yf.download(
    'GOOG',
    start=start_date,
    end=end_date,
    progress=False
)

data["Date"] = data.index
df1 = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]
df1.reset_index(drop=True, inplace=True)
df1.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2022-05-20  112.085503  112.550003  106.373001  109.313004  109.313004
# 1 2022-05-23  110.103996  112.005501  109.154251  111.666496  111.666496
# 2 2022-05-24  106.377502  106.394997  102.208000  105.926003  105.926003
# 3 2022-05-25  105.141998  106.544701  104.211250  105.839500  105.839500
# 4 2022-05-26  106.050499  108.955254  105.487999  108.295998  108.295998
#
#      Volume
# 0  37586000
# 1  31558000
# 2  60386000
# 3  37900000
# 4  30288000

# %%
figure = go.Figure(data=[go.Candlestick(
    x=df1["Date"],
    open=df1["Open"],
    high=df1["High"],
    low=df1["Low"],
    close=df1["Close"]
)])

figure.update_layout(title = "Google Stock Price Analysis", xaxis_rangeslider_visible=True)
figure.show()

# %%
figure = px.bar(df1, x="Date", y="Close")
figure.show()

# %%
figure = px.line(
    df1, 
    x='Date', y='Close',
    title='Stock Market Analysis with Rangeslider'
    )

figure.update_xaxes(rangeslider_visible=True)
figure.show()

# %%
figure = px.line(
    df1,
    x='Date', y='Close',
    title='Stock Market Analysis with Time Period Selectors'
)

figure.update_xaxes(
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=3, label="3m", step="month", stepmode="backward"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
figure.show()

# %%
figure = px.scatter(
    data,
    x='Date', y='Close',
    range_x=[d2, d1],
    title='Stock Market Analysis by Hiding Weekend Gaps'
)

figure.update_xaxes(
    rangebreaks=[
        dict(bounds=["sat", "mon"])
    ]
)
figure.update_xaxes(rangeslider_visible=True)

figure.show()
